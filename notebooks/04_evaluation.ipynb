# %% [markdown]
# # 04 - Evaluation
#
# Save the trained model accuracy to the results directory.

# %%
from pathlib import Path

project_root = Path.cwd()
if not (project_root / 'results').is_dir():
    project_root = project_root.parent
results_path = project_root / 'results' / 'metrics.txt'
if 'acc' not in globals() or acc is None:
    print('Evaluation skipped: train the model with both AI and Human samples first.')
else:
    with open(results_path, 'w', encoding='utf-8') as file:
        file.write(f'Random Forest Accuracy: {acc}\n')
    print(f'Metrics saved to {results_path}')
# Out:
# Evaluation skipped: train the model with both AI and Human samples first.
